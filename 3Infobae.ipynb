# %%
import pymongo
from pymongo import MongoClient
from requests.exceptions import ConnectionError
from bs4 import BeautifulSoup
import requests
import time

client = MongoClient("52.25.140.201",27017)
db = client['ProjectCorruption']

coll_articles = db['Articles']
coll_links = db['Links_to_articles']
coll_parsed = db['Parsed_Articles']

print coll_links
print coll_articles
print coll_parsed

# %%
from requests.exceptions import ConnectionError
from bs4 import BeautifulSoup
import requests
import time
#article_link = "http://www.infobae.com/2015/07/01/1738929-burlando-xipolitakis-no-estoy-defendiendo-la-mala-la-pelicula-hay-gente-que-roba-y-es-corrupta"

article_link = coll_links.find_one({"source":"Infobae", "parsed":"N"})
print article_link['link']
article_link['link']
response = requests.get(article_link['link'])
print response.status_code

# %%
from bs4 import BeautifulSoup
import requests

# %%
response = requests.get(article_link['link'])

# %%
print article_link['link'].__repr__()
print url.__repr__()

# %%
r.text == response.text

# %%
r.status_code
# Out:
# 200

# %%
url = "http://www.infobae.com/2015/08/31/1752145-ejecutivo-brasileno-aseguro-que-odebrecht-dirigia-el-cartel-empresas-que-operaba-petrobras"
r = requests.get(url)
print r.text
# Out:
#    <!DOCTYPE html>
# <!--[if lt IE 7 ]> <html itemscope itemtype="http://schema.org/Article" lang="es" class="no-js ie ie6" > <![endif]-->
# <!--[if IE 7 ]> <html itemscope itemtype="http://schema.org/Article" lang="es" class="no-js ie ie7" > <![endif]-->
# <!--[if IE 8 ]> <html itemscope itemtype="http://schema.org/Article" lang="es"class="no-js ie ie8" > <![endif]-->
# <!--[if IE 9 ]> <html itemscope itemtype="http://schema.org/Article" lang="es" class="no-js ie ie9" > <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html itemscope itemtype="http://schema.org/Article" lang="es" class="no-js" >
#   <!--<![endif]-->
#   <head>
#
# <link href="http://www.infobae.com//css/infobae/css/reset.css?v-1405369941" rel="stylesheet" type="text/css" \/>
# <link href="http://www.infobae.com//css/infobae/css/main.css?v-1440192062" rel="stylesheet" type="text/css" \/>
# <link href="http://www.infobae.com//css/infobae/css/america.css?v-1412719069" rel="stylesheet" type="text/css" \/>
# ...

# %%
agent = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.130 Safari/537.36"
r4 = requests.get(url, headers={'User-Agent': agent})
#BeautifulSoup(r4.text).find_all(class_='entry-title')

# %%
page = r4.text
soup = BeautifulSoup(page)

# %%
print soup.find(class_='entry-title').text
# Out:
# Ejecutivo brasileño aseguró que Odebrecht "dirigía el cartel de empresas" que operaba en Petrobras

# %%
print soup.find(class_='hide pubdate updated').text
# Out:
# 31-08-2015

# %%
print soup.find(class_='cuerposmart clearfix').text
# Out:
# Facebook
# Twitter
# Linkedin
# Google
# E-mail
# Imprimir
#
#
#
#
#  Crédito:
#
# ...

# %%
print soup.find(class_='cat cat-')['data-header-tag'] # volanta
# Out:
# Política
