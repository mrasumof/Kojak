# %%
import pymongo
from pymongo import MongoClient
from requests.exceptions import ConnectionError
from bs4 import BeautifulSoup
import requests
import time

client = MongoClient("52.25.140.201",27017)
db = client['ProjectCorruption']

coll_articles = db['Articles']
coll_links = db['Links_to_articles']
coll_parsed = db['Parsed_Articles']

print coll_links
print coll_articles
print coll_parsed
# Out:
# Collection(Database(MongoClient('52.25.140.201', 27017), u'ProjectCorruption'), u'Links_to_articles')
# Collection(Database(MongoClient('52.25.140.201', 27017), u'ProjectCorruption'), u'Articles')
# Collection(Database(MongoClient('52.25.140.201', 27017), u'ProjectCorruption'), u'Parsed_Articles')

# %%
article_link = "http://www.lanacion.com.ar/1820989"
response = requests.get(article_link)
print response.status_code
# Out:
# 200

# %%
page = response.text
soup = BeautifulSoup(page)

# %%
print soup.encode('latin1').decode('utf8')
# Out:
# <html><body><p>﻿<!DOCTYPE html>
# ...

# %%
print soup.find(class_='volanta').text
# Out:
# Libro

# %%
print soup.find(class_='volanta').text.encode('latin1').decode('utf8')
# Out:
# Libro

# %%
print soup.find('h1').text.encode('latin1').decode('utf8') #title
# Out:
# Duro diagnóstico sobre la corrupción en el Poder Judicial

# %%
soup.find(class_='bajada').text

#print soup.find(class_='bajada').text.encode('latin1').decode('utf8') #subtitle
# Out:
# u'En una presentaci\xc3\xb3n en el Colegio de Abogados se puso el foco en las decisiones judiciales que benefician a los poderosos'

# %%
print soup.find(id='cuerpo').text.encode('latin1').decode('utf8') #body
# Out:
# En el Colegio de Abogados de la Ciudad de Buenos Aires se presentó el libro Cosa juzgada fraudulenta. Un ensayo sobre la cosa juzgada írrita, del abogado Federico Morgenstern. La presentación puso en primer plano la existencia de corrupción en la Justicia para garantizar impunidad a funcionarios poderosos.La posibilidad de reabrir causas por el recurso de cosa juzgada fraudulenta fue el punto que disparó las exposiciones de los panelistas: los abogados María Angélica Gelli y Máximo Fonrouge; el historiador Luis Alberto Romero, y el periodista de LA NACION Carlos Pagni. Y en sus planteos fue central remarcar que la corrupción judicial es fuente de impunidad.Gelli mostró indignación al referirse a las presiones sobre los jueces. Habló de "interferencias sobre el Poder Judicial" y cuestionó que estas situaciones se han naturalizado y no se genera "presión social" para que cesen."Una democracia es fuerte cuando los justiciables tienen garantías y responsabilidades, aun cuando son funcion
# ...

# %%
soup.find(class_='fecha')['content'].encode('utf8')
#.encode('latin1')
#.decode('utf8') #date
date = soup.find(class_='fecha')['content']
date
date2 = date.encode('utf8')
date2
# Out:
# 'Viernes 21 de agosto de 2015'

# %%
import dateparser

date_str = soup.find(class_='fecha')['content'].encode('latin1').decode('utf8')
print date_str

date_object = dateparser.parse(date_str)
print date_object
# Out:
# Viernes 21 de agosto de 2015
# 2015-08-21 00:00:00
