# %%
import time
import requests
import json
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from requests.exceptions import ConnectionError

import pymongo
from pymongo import MongoClient
client = MongoClient("52.25.140.201",27017)
db = client['ProjectCorruption']
print db
collection = db['Links_to_articles']
print collection

starting_point = 0
# Out:
# Database(MongoClient('52.25.140.201', 27017), u'ProjectCorruption')
# Collection(Database(MongoClient('52.25.140.201', 27017), u'ProjectCorruption'), u'Links_to_articles')

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

chrome = webdriver.Chrome()

pagina12_url = "http://www.pagina12.com.ar/usuarios/login.php?path=/buscador/index.php"

chrome.get(pagina12_url)

# %%
login_form = chrome.find_element_by_name("email")
login_form.send_keys("mrasumof@yahoo.com")

# %%
login_form = chrome.find_element_by_name("clave")
login_form.send_keys("rachu4")

# %%
compose_button = chrome.find_element_by_name('ingresar')
compose_button.click()

# %%
search_form = chrome.find_element_by_name("q")
search_form.text
# Out:
# u''

# %%
search_form = chrome.find_elements_by_name("q")
search_form[1].send_keys("+corrupcion +corrupto +corrupta +cohecho +soborno +coima +nepotismo +fraude +clientelismo")

# %%
from selenium.webdriver.support.ui import Select
select = Select(chrome.find_element_by_name("r"))
select.select_by_value("100")

# %%
search_button = chrome.find_element_by_name("submit")
search_button.click()

# %%
print chrome.current_url
url = chrome.current_url
# Out:
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.0

# %%
page = chrome.page_source

# %%
soup = BeautifulSoup(page)

# %%
a = soup.find_all('a')
count = 0
for each in range(len(a)):
    if a[each].get('title') is not None:
        if 'Ir a la nota' in a[each].get('title'):
            print a[each]['href']
            count += 1
            
print count
# Out:
# /diario/deportes/8-280399-2015-08-29.html
# /diario/elmundo/4-280410-2015-08-29.html
# /diario/elpais/1-280458-2015-08-29.html
# /diario/elpais/1-280460-2015-08-29.html
# /diario/elpais/1-280469-2015-08-29.html
# /diario/elpais/subnotas/280458-74160-2015-08-29.html
# /diario/ultimas/20-280387-2015-08-28.html
# /diario/elmundo/4-280327-2015-08-28.html
# /diario/elmundo/4-280332-2015-08-28.html
# /diario/deportes/8-280345-2015-08-28.html
# /diario/elpais/1-280380-2015-08-28.html
# /diario/elpais/1-280381-2015-08-28.html
# /diario/elpais/1-280382-2015-08-28.html
# /diario/elpais/1-280383-2015-08-28.html
# /diario/ultimas/20-280390-2015-08-28.html
# /diario/ultimas/20-280393-2015-08-28.html
# /diario/elpais/subnotas/280376-74146-2015-08-28.html
# /diario/elpais/subnotas/280382-74148-2015-08-28.html
# /diario/elpais/1-280252-2015-08-27.html
# /diario/elpais/1-280271-2015-08-27.html
# /diario/elpais/1-280277-2015-08-27.html
# /diario/elpais/1-280279-2015-08-27.html
# /diario/elpais/1-280280-2015-08-27.html
# /diario/elpais/1-280281-2015-08-27.html
# /diario/elpais/1-280284-2015-08-27.html
# /diario/ultimas/20-280299-2015-08-27.html
# /diario/ultimas/20-280300-2015-08-27.html
# /diario/ultimas/20-280308-2015-08-27.html
# /diario/elpais/subnotas/280279-74133-2015-08-27.html
# /diario/suplementos/espectaculos/10-36484-2015-08-27.html
# /diario/elmundo/4-280154-2015-08-26.html
# /diario/elpais/1-280170-2015-08-26.html
# /diario/elpais/1-280171-2015-08-26.html
# /diario/elpais/1-280206-2015-08-26.html
# /diario/ultimas/20-280212-2015-08-26.html
# /diario/ultimas/20-280213-2015-08-26.html
# /diario/ultimas/20-280222-2015-08-26.html
# /diario/elpais/subnotas/280172-74118-2015-08-26.html
# /diario/ultimas/subnotas/280213-74125-2015-08-26.html
# /diario/ultimas/20-280131-2015-08-25.html
# /diario/deportes/8-280068-2015-08-25.html
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.3200
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.3300
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.3400
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.3500
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.3600
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.3700
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.3800
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.3900
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.4000
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.4100
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.4200
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.4300
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.4400
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.4500
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.4600
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.4700
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.4800
# http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.4900

# %%
total_added = 0
for each_search in search_pages:
    print "Page:"+each_search

    #response = requests.get(each_search)
    response = chrome.get(pagina12_url)
    page = chrome.page_source
    soup = BeautifulSoup(page)

    a = soup.find_all('a')
#    print response.status_code

    for link in a:
        if link.get('title') is not None:
            if 'Ir a la nota' in link.get('title'):
                article_link = 'www.pagina12.com.ar'+link['href'] 
                exist = collection.find_one({"link": article_link, "source":"Pagina12"})
                if exist == None:
                    article_source = "Pagina12"
                    article_object = {"link":article_link, "source":article_source}
                    article_id = collection.insert_one(article_object)
                    total_added += 1
                    print 'Link added:',article_link
                    print 'Total added:',str(total_added)
                else:
                    print 'Link passed:',article_link
# Out:
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.0
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.100
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.200
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.300
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.400
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.500
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=aa3530ac145bad3e60aee4b644393dc5.600

# %%
flag = 1

for each_search in search_pages:
    while True:
        try:
            response = requests.get(each_search)
        except ConnectionError:
            print "Oopss...we've been cut off... :( Let's take some time off :)"

        if response.status_code != 200:
            print "Sleeping..."
            time.sleep(12)
        else:
            print "New Page"
            print response.status_code
            page = response.text
            soup = BeautifulSoup(page)
            break

    print "Page:"+each_search
    
    a = soup.find_all('a')
    print len(a)
    for link in a:
        '''print "Link:",link
        print "len:",len(link)
        print "Rangelen:",range(len(link))
        print "each:",each'''

        if link.get('title') is not None:
            if 'Ir a la nota' in link.get('title'):
                article_link = 'www.pagina12.com.ar/'+['href'] 
                exist = collection.find_one({"link": article_link, "source":"Pagina12"})
                if exist == None:
                    article_source = "Pagina12"
                    article_object = {"link":article_link, "source":article_source}
                    article_id = collection.insert_one(article_object)
                    total_added += 1
                    print 'Link added:',article_link
                    print 'Total added:',str(total_added)
                else:
                    print 'Link passed:',article_link
            
    site_page += 1
# Out:
# New Page
# 200
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=14273cbe3a6454c269e2881b50a553ba.0
# 58
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# New Page
# 200
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=14273cbe3a6454c269e2881b50a553ba.100
# 58
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# New Page
# 200
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=14273cbe3a6454c269e2881b50a553ba.200
# 58
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# New Page
# 200
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=14273cbe3a6454c269e2881b50a553ba.300
# 58
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# New Page
# 200
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=14273cbe3a6454c269e2881b50a553ba.400
# 58
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# New Page
# 200
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=14273cbe3a6454c269e2881b50a553ba.500
# 58
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# New Page
# 200
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=14273cbe3a6454c269e2881b50a553ba.600
# 58
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# New Page
# 200
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=14273cbe3a6454c269e2881b50a553ba.700
# 58
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# New Page
# 200
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=14273cbe3a6454c269e2881b50a553ba.800
# 58
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# New Page
# 200
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=14273cbe3a6454c269e2881b50a553ba.900
# 58
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# New Page
# 200
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=14273cbe3a6454c269e2881b50a553ba.1000
# 58
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# New Page
# 200
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=14273cbe3a6454c269e2881b50a553ba.1100
# 58
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# New Page
# 200
# Page:http://www.pagina12.com.ar/buscador/resultado.php?qid=14273cbe3a6454c269e2881b50a553ba.1200
# 58
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-169-1eeae9860454> in <module>()
#       5     while True:
#       6         try:
# ----> 7             response = requests.get(each_search)
#       8         except ConnectionError:
#       9             print "Oopss...we've been cut off... :( Let's take some time off :)"
#
# //anaconda/lib/python2.7/site-packages/requests/api.pyc in get(url, **kwargs)
#      53
#      54     kwargs.setdefault('allow_redirects', True)
# ---> 55     return request('get', url, **kwargs)
#      56
#      57
#
# //anaconda/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      42
#      43     session = sessions.Session()
# ---> 44     return session.request(method=method, url=url, **kwargs)
#      45
#      46
#
# //anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert)
#     454             'allow_redirects': allow_redirects,
#     455         }
# --> 456         resp = self.send(prep, **send_kwargs)
#     457
#     458         return resp
#
# //anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     583
#     584         # Resolve redirects if allowed.
# --> 585         history = [resp for resp in gen] if allow_redirects else []
#     586
#     587         # Shuffle things around if there's history.
#
# //anaconda/lib/python2.7/site-packages/requests/sessions.pyc in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies)
#     177                 cert=cert,
#     178                 proxies=proxies,
# --> 179                 allow_redirects=False,
#     180             )
#     181
#
# //anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     557
#     558         # Send the request
# --> 559         r = adapter.send(request, **kwargs)
#     560
#     561         # Total elapsed time of the request (approximately)
#
# //anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     325                     decode_content=False,
#     326                     retries=self.max_retries,
# --> 327                     timeout=timeout
#     328                 )
#     329
#
# //anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     491             httplib_response = self._make_request(conn, method, url,
#     492                                                   timeout=timeout,
# --> 493                                                   body=body, headers=headers)
#     494
#     495             # If we're going to release the connection in ``finally:``, then
#
# //anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     317         try:
#     318             try: # Python 2.7+, use buffering of HTTP responses
# --> 319                 httplib_response = conn.getresponse(buffering=True)
#     320             except TypeError: # Python 2.6 and older
#     321                 httplib_response = conn.getresponse()
#
# //anaconda/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1130
#    1131         try:
# -> 1132             response.begin()
#    1133             assert response.will_close != _UNKNOWN
#    1134             self.__state = _CS_IDLE
#
# //anaconda/lib/python2.7/httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# //anaconda/lib/python2.7/httplib.pyc in _read_status(self)
#     407     def _read_status(self):
#     408         # Initialize with Simple-Response defaults
# --> 409         line = self.fp.readline(_MAXLINE + 1)
#     410         if len(line) > _MAXLINE:
#     411             raise LineTooLong("header line")
#
# //anaconda/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:
