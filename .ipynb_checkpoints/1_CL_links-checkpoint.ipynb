# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

#url = 'http://www.clarin.com/buscador?q=corrupcion'
url = 'https://www.googleapis.com/customsearch/v1element?key=AIzaSyCVAXiUzRYsML1Pv6RwSG1gunmMikTzQqY&rsz=filtered_cse&num=10&hl=es&prettyPrint=false&source=gcsc&gss=.com&sig=56f70d816baa48bdfe9284ebc883ad41&start=10&cx=002843853682434280739:x9oyo5xw8ls&q=corrupcion&sort=&googlehost=www.google.com&callback=google.search.Search.apiary19326&nocache=1440530302936'
response = requests.get(url)
print response
# Out:
# <Response [200]>

# %%
page = response.text
print page
# Out:
# // API callback
# google.search.Search.apiary19326({"cursor":{"currentPageIndex":1,"estimatedResultCount":"4910","moreResultsUrl":"http://www.google.com/cse?oe=utf8&ie=utf8&source=uds&q=corrupcion&start=10&sort=&cx=002843853682434280739:x9oyo5xw8ls","resultCount":"4.910","searchResultTime":"0,34","pages":[{"label":1,"start":"0"},{"label":2,"start":"10"},{"label":3,"start":"20"},{"label":4,"start":"30"},{"label":5,"start":"40"},{"label":6,"start":"50"},{"label":7,"start":"60"},{"label":8,"start":"70"},{"label":9,"start":"80"},{"label":10,"start":"90"}]},"context":{"title":"Clarin.com","total_results":"1105","facets":[]},"results":[{"GsearchResultClass":"GwebSearch","cacheUrl":"http://www.google.com/search?q=cache:RAzFd3IasBYJ:www.clarin.com","clicktrackUrl":"https://www.google.com/url?q=http://www.clarin.com/politica/sospechas-corrupcion-negocios-Venezuela_0_1169883059.html&sa=U&ved=0CAUQFjAAOApqFQoTCJeiw7n4xscCFYZakgodNyUNNQ&client=internal-uds-cse&usg=AFQjCNHjkmtPdK3C20rxabeVLPpc5CAYbA","content":"6 Jul 2014 \u003cb\u003e...\u003c/b\u003e Lo usual es que los hechos de \u003cb\u003ecorrupción\u003c/b\u003e sean denunciados por una persona, \no a lo sumo por una empresa. Este caso es inédito, porque&nbsp;...","contentNoFormatting":"6 Jul 2014 ... Lo usual es que los hechos de corrupción sean denunciados por una persona, \no a lo sumo por una empresa. Este caso es inédito, porque ...","formattedUrl":"www.clarin.com/.../sospechas-\u003cb\u003ecorrupcion\u003c/b\u003e-negocios-Venezuela_0_ 1169883059.html","title":"Más sospechas de \u003cb\u003ecorrupción\u003c/b\u003e en los negocios con Venezuela","titleNoFormatting":"Más sospechas de corrupción en los negocios con Venezuela","unescapedUrl":"http://www.clarin.com/politica/sospechas-corrupcion-negocios-Venezuela_0_1169883059.html","url":"http://www.clarin.com/politica/sospechas-corrupcion-negocios-Venezuela_0_1169883059.html","visibleUrl":"www.clarin.com","richSnippet":{"cseImage":{"src":"http://www.clarin.com/politica/Vinculos-Hugo-Chavez-Cheppi-Vignati_CLAIMA20140706_0040_4.jpg"},"cseThumbnail":{"width":"299","height":"168","src":"https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRSKYlvHXfXRDMhojiQ9aEIe4kPq_ZQkYnvh9v9SFNmg5BIMxodqNSrjxs"},"metatags":{"language":"es","distribution":"Global","author":"Clarin.com","classification":"noticias, información, videos, diario, newspaper","subject":"Clarin.com | Diario Clarin","abstract":"Clarin.com noticias de la Argentina y el mundo actualizadas las 24 horas","applicationName":"Clarin.com","fbPageId":"156057357762712","fbAdmins":"100006394091211","ogUrl":"http://www.clarin.com/politica/sospechas-corrupcion-negocios-Venezuela_0_1169883059.html","ogTitle":"Más sospechas de corrupción en los negocios con Venezuela","ogImage":"http://www.clarin.com/politica/Vinculos-Hugo-Chavez-Cheppi-Vignati_CLAIMA20140706_0040_4.jpg","cxenseparseRecsSquareimage":"http://www.clarin.com/politica/Vinculos-Hugo-Chavez-Cheppi-Vignati_CLAIMA20140706_0040_13.jpg","ogType":"article","ogSection":"Política","ogSiteName":"Clarin.com","twitterCard":"summary_large_image","twitterImageSrc":"http://www.clarin.com/politica/Vinculos-Hugo-Chavez-Cheppi-Vignati_CLAIMA20140706_0040_4.jpg","twitterSite":"@clarincom","twitterTitle":"Más sospechas de corrupción en los negocios con Venezuela","twitterDescription":"La firma Bioart SA ya exportó 37.000 toneladas de arroz por valores muy superiores a los del mercado.","twitterCreator":"@clarincom","twitterDomain":"clarin.com","cxenseparsePageclass":"article","cxenseparseRecsArticleid":"CLANWS20140706_0059","cxenseparseRecsPublishtime":"2014-07-06T08:07:00.000-0300","cxenseparseGcaCategories":"politica"}}},{"GsearchResultClass":"GwebSearch","cacheUrl":"http://www.google.com/search?q=cache:jNb0DxXq7mQJ:www.clarin.com","clicktrackUrl":"https://www.google.com/url?q=http://www.clarin.com/opinion/federalismo-corrupcion-gobierno-Diaz_Cayeros_0_1387661628.html&sa=U&ved=0CAgQFjABOApqFQoTCJeiw7n4xscCFYZakgodNyUNNQ&client=internal-uds-cse&usg=AFQjCNFqH0ZLg ...

# %%
#page.encode('latin1').decode('utf8')
print type(page)
print len(page)
obj_json = page[49:31830]
print obj_json
# Out:
# <type 'unicode'>
# 31746
# {"cursor":{"currentPageIndex":1,"estimatedResultCount":"4910","moreResultsUrl":"http://www.google.com/cse?oe=utf8&ie=utf8&source=uds&q=corrupcion&start=10&sort=&cx=002843853682434280739:x9oyo5xw8ls","resultCount":"4.910","searchResultTime":"0,24","pages":[{"label":1,"start":"0"},{"label":2,"start":"10"},{"label":3,"start":"20"},{"label":4,"start":"30"},{"label":5,"start":"40"},{"label":6,"start":"50"},{"label":7,"start":"60"},{"label":8,"start":"70"},{"label":9,"start":"80"},{"label":10,"start":"90"}]},"context":{"title":"Clarin.com","total_results":"1105","facets":[]},"results":[{"GsearchResultClass":"GwebSearch","cacheUrl":"http://www.google.com/search?q=cache:RAzFd3IasBYJ:www.clarin.com","clicktrackUrl":"https://www.google.com/url?q=http://www.clarin.com/politica/sospechas-corrupcion-negocios-Venezuela_0_1169883059.html&sa=U&ved=0CAUQFjAAOApqFQoTCPqrnOj2xscCFYpDkgodWQ0CgQ&client=internal-uds-cse&usg=AFQjCNHjkmtPdK3C20rxabeVLPpc5CAYbA","content":"6 Jul 2014 \u003cb\u003e...\u003c/b\u003e Lo usual es que los hechos de \u003cb\u003ecorrupción\u003c/b\u003e sean denunciados por una persona, \no a lo sumo por una empresa. Este caso es inédito, porque&nbsp;...","contentNoFormatting":"6 Jul 2014 ... Lo usual es que los hechos de corrupción sean denunciados por una persona, \no a lo sumo por una empresa. Este caso es inédito, porque ...","formattedUrl":"www.clarin.com/.../sospechas-\u003cb\u003ecorrupcion\u003c/b\u003e-negocios-Venezuela_0_ 1169883059.html","title":"Más sospechas de \u003cb\u003ecorrupción\u003c/b\u003e en los negocios con Venezuela","titleNoFormatting":"Más sospechas de corrupción en los negocios con Venezuela","unescapedUrl":"http://www.clarin.com/politica/sospechas-corrupcion-negocios-Venezuela_0_1169883059.html","url":"http://www.clarin.com/politica/sospechas-corrupcion-negocios-Venezuela_0_1169883059.html","visibleUrl":"www.clarin.com","richSnippet":{"cseImage":{"src":"http://www.clarin.com/politica/Vinculos-Hugo-Chavez-Cheppi-Vignati_CLAIMA20140706_0040_4.jpg"},"cseThumbnail":{"width":"299","height":"168","src":"https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRSKYlvHXfXRDMhojiQ9aEIe4kPq_ZQkYnvh9v9SFNmg5BIMxodqNSrjxs"},"metatags":{"language":"es","distribution":"Global","author":"Clarin.com","classification":"noticias, información, videos, diario, newspaper","subject":"Clarin.com | Diario Clarin","abstract":"Clarin.com noticias de la Argentina y el mundo actualizadas las 24 horas","applicationName":"Clarin.com","fbPageId":"156057357762712","fbAdmins":"100006394091211","ogUrl":"http://www.clarin.com/politica/sospechas-corrupcion-negocios-Venezuela_0_1169883059.html","ogTitle":"Más sospechas de corrupción en los negocios con Venezuela","ogImage":"http://www.clarin.com/politica/Vinculos-Hugo-Chavez-Cheppi-Vignati_CLAIMA20140706_0040_4.jpg","cxenseparseRecsSquareimage":"http://www.clarin.com/politica/Vinculos-Hugo-Chavez-Cheppi-Vignati_CLAIMA20140706_0040_13.jpg","ogType":"article","ogSection":"Política","ogSiteName":"Clarin.com","twitterCard":"summary_large_image","twitterImageSrc":"http://www.clarin.com/politica/Vinculos-Hugo-Chavez-Cheppi-Vignati_CLAIMA20140706_0040_4.jpg","twitterSite":"@clarincom","twitterTitle":"Más sospechas de corrupción en los negocios con Venezuela","twitterDescription":"La firma Bioart SA ya exportó 37.000 toneladas de arroz por valores muy superiores a los del mercado.","twitterCreator":"@clarincom","twitterDomain":"clarin.com","cxenseparsePageclass":"article","cxenseparseRecsArticleid":"CLANWS20140706_0059","cxenseparseRecsPublishtime":"2014-07-06T08:07:00.000-0300","cxenseparseGcaCategories":"politica"}}},{"GsearchResultClass":"GwebSearch","cacheUrl":"http://www.google.com/search?q=cache:jNb0DxXq7mQJ:www.clarin.com","clicktrackUrl":"https://www.google.com/url?q=http://www.clarin.com/opinion/federalismo-corrupcion-gobierno-Diaz_Cayeros_0_1387661628.html&sa=U&ved=0CAgQFjABOApqFQoTCPqrnOj2xscCFYpDkgodWQ0CgQ&client=internal-uds-cse&usg=AFQjCNFqH0ZLg0XNhqzZauz_uAvZv82mGA","content": ...

# %%
import json

object_json = json.loads(obj_json)

#print object_son

print json.dumps(object_json, indent=4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-cf97c61f62fd> in <module>()
#       1 import json
#       2
# ----> 3 object_json = json.loads(obj_json)
#       4
#       5 #print object_son
#
# //anaconda/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     336             parse_int is None and parse_float is None and
#     337             parse_constant is None and object_pairs_hook is None and not kw):
# --> 338         return _default_decoder.decode(s)
#     339     if cls is None:
#     340         cls = JSONDecoder
#
# //anaconda/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     367         end = _w(s, end).end()
#     368         if end != len(s):
# --> 369             raise ValueError(errmsg("Extra data", s, end, len(s)))
#     370         return obj
#     371
#
# ValueError: Extra data: line 1 column 31696 - line 1 column 31698 (char 31695 - 31697)

# %%
print type(object_json)
# Out:
# <type 'dict'>

# %%
print len(object_json["results"])
# Out:
# 10

# %%
print object_json[u"results"][0][u'content']
# Out:
# 6 Jul 2014 <b>...</b> Lo usual es que los hechos de <b>corrupción</b> sean denunciados por una persona,
# o a lo sumo por una empresa. Este caso es inédito, porque&nbsp;...

# %%
print object_json[u"results"][0][u"title"]
# Out:
# Más sospechas de <b>corrupción</b> en los negocios con Venezuela

# %%
print object_json[u"results"][0][u"clicktrackUrl"]
# Out:
# https://www.google.com/url?q=http://www.clarin.com/politica/sospechas-corrupcion-negocios-Venezuela_0_1169883059.html&sa=U&ved=0CAUQFjAAOApqFQoTCIzFpemDxccCFUuhgAodZPEGkQ&client=internal-uds-cse&usg=AFQjCNHjkmtPdK3C20rxabeVLPpc5CAYbA

# %%
page = response.text
soup = BeautifulSoup(page)

print soup
# Out:
# <html><body><p>// API callback
# google.search.Search.apiary19326({"cursor":{"currentPageIndex":1,"estimatedResultCount":"4910","moreResultsUrl":"http://www.google.com/cse?oe=utf8&amp;ie=utf8&amp;source=uds&amp;q=corrupcion&amp;start=10&amp;sort=&amp;cx=002843853682434280739:x9oyo5xw8ls","resultCount":"4.910","searchResultTime":"0,21","pages":[{"label":1,"start":"0"},{"label":2,"start":"10"},{"label":3,"start":"20"},{"label":4,"start":"30"},{"label":5,"start":"40"},{"label":6,"start":"50"},{"label":7,"start":"60"},{"label":8,"start":"70"},{"label":9,"start":"80"},{"label":10,"start":"90"}]},"context":{"title":"Clarin.com","total_results":"1104","facets":[]},"results":[{"GsearchResultClass":"GwebSearch","cacheUrl":"http://www.google.com/search?q=cache:RAzFd3IasBYJ:www.clarin.com","clicktrackUrl":"https://www.google.com/url?q=http://www.clarin.com/politica/sospechas-corrupcion-negocios-Venezuela_0_1169883059.html&amp;sa=U&amp;ved=0CAUQFjAAOApqFQoTCOacgv7jxscCFQQakgodzKIGEA&amp;client=internal-uds-cse&amp;usg=AFQjCNHjkmtPdK3C20rxabeVLPpc5CAYbA","content":"6 Jul 2014 \u003cb\u003e...\u003c/b\u003e Lo usual es que los hechos de \u003cb\u003ecorrupción\u003c/b\u003e sean denunciados por una persona, \no a lo sumo por una empresa. Este caso es inédito, porque ...","contentNoFormatting":"6 Jul 2014 ... Lo usual es que los hechos de corrupción sean denunciados por una persona, \no a lo sumo por una empresa. Este caso es inédito, porque ...","formattedUrl":"www.clarin.com/.../sospechas-\u003cb\u003ecorrupcion\u003c/b\u003e-negocios-Venezuela_0_ 1169883059.html","title":"Más sospechas de \u003cb\u003ecorrupción\u003c/b\u003e en los negocios con Venezuela","titleNoFormatting":"Más sospechas de corrupción en los negocios con Venezuela","unescapedUrl":"http://www.clarin.com/politica/sospechas-corrupcion-negocios-Venezuela_0_1169883059.html","url":"http://www.clarin.com/politica/sospechas-corrupcion-negocios-Venezuela_0_1169883059.html","visibleUrl":"www.clarin.com","richSnippet":{"cseImage":{"src":"http://www.clarin.com/politica/Vinculos-Hugo-Chavez-Cheppi-Vignati_CLAIMA20140706_0040_4.jpg"},"cseThumbnail":{"width":"299","height":"168","src":"https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRSKYlvHXfXRDMhojiQ9aEIe4kPq_ZQkYnvh9v9SFNmg5BIMxodqNSrjxs"},"metatags":{"language":"es","distribution":"Global","author":"Clarin.com","classification":"noticias, información, videos, diario, newspaper","subject":"Clarin.com | Diario Clarin","abstract":"Clarin.com noticias de la Argentina y el mundo actualizadas las 24 horas","applicationName":"Clarin.com","fbPageId":"156057357762712","fbAdmins":"100006394091211","ogUrl":"http://www.clarin.com/politica/sospechas-corrupcion-negocios-Venezuela_0_1169883059.html","ogTitle":"Más sospechas de corrupción en los negocios con Venezuela","ogImage":"http://www.clarin.com/politica/Vinculos-Hugo-Chavez-Cheppi-Vignati_CLAIMA20140706_0040_4.jpg","cxenseparseRecsSquareimage":"http://www.clarin.com/politica/Vinculos-Hugo-Chavez-Cheppi-Vignati_CLAIMA20140706_0040_13.jpg","ogType":"article","ogSection":"Política","ogSiteName":"Clarin.com","twitterCard":"summary_large_image","twitterImageSrc":"http://www.clarin.com/politica/Vinculos-Hugo-Chavez-Cheppi-Vignati_CLAIMA20140706_0040_4.jpg","twitterSite":"@clarincom","twitterTitle":"Más sospechas de corrupción en los negocios con Venezuela","twitterDescription":"La firma Bioart SA ya exportó 37.000 toneladas de arroz por valores muy superiores a los del mercado.","twitterCreator":"@clarincom","twitterDomain":"clarin.com","cxenseparsePageclass":"article","cxenseparseRecsArticleid":"CLANWS20140706_0059","cxenseparseRecsPublishtime":"2014-07-06T08:07:00.000-0300","cxenseparseGcaCategories":"politica"}}},{"GsearchResultClass":"GwebSearch","cacheUrl":"http://www.google.com/search?q=cache:jNb0DxXq7mQJ:www.clarin.com","clicktrackUrl":"https://www.google.com/url?q=http://www.clarin.com/opinion/federalismo-corrupcion-gobierno-Diaz_Cayeros_0_1387661628.html&amp;sa=U&amp;ved=0CAgQFjABOApqFQoTCOacgv7jxscCFQQakgodzKIGE ...

# %%
https://www.googleapis.com/customsearch/v1element?key=AIzaSyCVAXiUzRYsML1Pv6RwSG1gunmMikTzQqY&
    rsz=filtered_cse&num=10&hl=es&prettyPrint=false&source=gcsc&gss=.com&sig=56f70d816baa48bdfe9284ebc883ad41&
    start=10&cx=002843853682434280739:x9oyo5xw8ls&q=corrupcion&sort=&googlehost=www.google.com&
        callback=google.search.Search.apiary19326&nocache=1440530302936'

# %%
https://www.googleapis.com/customsearch/v1element?key=AIzaSyCVAXiUzRYsML1Pv6RwSG1gunmMikTzQqY&rsz=filtered_cse&num=10&hl=es&prettyPrint=false&source=gcsc&gss=.com&sig=56f70d816baa48bdfe9284ebc883ad41&start=20&cx=002843853682434280739:x9oyo5xw8ls&q=corrupcion&sort=&googlehost=www.google.com&callback=google.search.Search.apiary19326&nocache=1440530302936'

# %%
import time
import requests
import json
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from requests.exceptions import ConnectionError

import pymongo
from pymongo import MongoClient
client = MongoClient("52.25.140.201",27017)
db = client['ProjectCorruption']
print db
collection = db['Links_to_articles']
print collection

starting_point = 0
url = 'https://www.googleapis.com/customsearch/v1element?key=AIzaSyCVAXiUzRYsML1Pv6RwSG1gunmMikTzQqY&rsz=filtered_cse&num=10&hl=es&prettyPrint=false&source=gcsc&gss=.com&sig=56f70d816baa48bdfe9284ebc883ad41&start=10&cx=002843853682434280739:x9oyo5xw8ls&q=corrupcion&sort=&googlehost=www.google.com&callback=google.search.Search.apiary19326&nocache=1440530302936'

site_page = 1

object_json = json.loads(page[49:31847])

response = requests.get(url)

while ((response.status_code == 200)):

    print "Page:",site_page
    
    for each in range(len(object_json["results"])):
        has = object_json[u"results"][each][u"clicktrackUrl"]
        if has != None:
            if 'http://www.clarin.com/' in has:
                article_link = has
                article_source = "Clarin"
                
                # Only adding the link if it is not existent currently
                exist = collection.find_one({"link": article_link})
                if exist == None:
                    article_object = {"link":article_link, "source":article_source}
                    article_id = collection.insert_one(article_object)
                    print 'Link added:',article_link
                else:
                    print 'Link passed:',article_link
                     
    url_1 = 'https://www.googleapis.com/customsearch/v1element?key=AIzaSyCVAXiUzRYsML1Pv6RwSG1gunmMikTzQqY&rsz=filtered_cse&num=10&hl=es&prettyPrint=false&source=gcsc&gss=.com&sig=56f70d816baa48bdfe9284ebc883ad41&start='
    site_page = site_page + 1
    url_page = str(site_page*10)
    url_2 = '&cx=002843853682434280739:x9oyo5xw8ls&q=corrupcion&sort=&googlehost=www.google.com&callback=google.search.Search.apiary19326&nocache=1440530302936'
    
    url = url_1+site_page+url_2
    
    resp_code = 1
    
    while True:
        try:
            response = requests.get(url)
        except ConnectionError:
            print "Oopss...we've been cut off... :( Let's take some time off :)"

        if response.status_code != 200:
            print "Sleeping..."
            time.sleep(12)
        else:
            break

print 'Grand Total added:',str(total_added)
# Out:
# Database(MongoClient('52.25.140.201', 27017), u'ProjectCorruption')
# Collection(Database(MongoClient('52.25.140.201', 27017), u'ProjectCorruption'), u'Links_to_articles')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-8e081bf73935> in <module>()
#      20 site_page = 1
#      21
# ---> 22 object_json = json.loads(page[49:31847])
#      23
#      24 response = requests.get(url)
#
# //anaconda/lib/python2.7/json/__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     336             parse_int is None and parse_float is None and
#     337             parse_constant is None and object_pairs_hook is None and not kw):
# --> 338         return _default_decoder.decode(s)
#     339     if cls is None:
#     340         cls = JSONDecoder
#
# //anaconda/lib/python2.7/json/decoder.pyc in decode(self, s, _w)
#     367         end = _w(s, end).end()
#     368         if end != len(s):
# --> 369             raise ValueError(errmsg("Extra data", s, end, len(s)))
#     370         return obj
#     371
#
# ValueError: Extra data: line 1 column 31696 - line 1 column 31698 (char 31695 - 31697)
