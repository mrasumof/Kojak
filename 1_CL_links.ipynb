# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

#url = 'http://www.clarin.com/buscador?q=corrupcion'
url = 'https://www.googleapis.com/customsearch/v1element?key=AIzaSyCVAXiUzRYsML1Pv6RwSG1gunmMikTzQqY&rsz=filtered_cse&num=10&hl=es&prettyPrint=false&source=gcsc&gss=.com&sig=56f70d816baa48bdfe9284ebc883ad41&start=10&cx=002843853682434280739:x9oyo5xw8ls&q=corrupto&sort=&googlehost=www.google.com&callback=google.search.Search.apiary7242&nocache=1440602392013'
response = requests.get(url)
print response
# Out:
# <Response [200]>

# %%
page = response.text
print page
# Out:
# // API callback
# ...

# %%
#page.encode('latin1').decode('utf8')
print type(page)
a = len(page)
print a
pos = page.index('{')
obj_json = page[pos:a-2]
#print page
print obj_json
print len(obj_json)
# Out:
# <type 'unicode'>
# 25692
# ...

# %%
import json

pos = page.index('{')
a = len(page)
object_json = json.loads(page[pos:a-2])

#print object_son

print json.dumps(object_json, indent=4)
# Out:
# {
#     "cursor": {
#         "moreResultsUrl": "http://www.google.com/cse?oe=utf8&ie=utf8&source=uds&q=corrupto&start=10&sort=&cx=002843853682434280739:x9oyo5xw8ls",
#         "estimatedResultCount": "9200",
#         "searchResultTime": "0,27",
#         "resultCount": "9.200",
#         "pages": [
#             {
#                 "start": "0",
#                 "label": 1
#             },
#             {
#                 "start": "10",
#                 "label": 2
#             },
#             {
#                 "start": "20",
#                 "label": 3
#             },
#             {
#                 "start": "30",
#                 "label": 4
#             },
#             {
#                 "start": "40",
#                 "label": 5
#             },
#             {
#                 "start": "50",
#                 "label": 6
#             },
#             {
#                 "start": "60",
#                 "label": 7
#             },
#             {
# ...

# %%
print type(object_json)
# Out:
# <type 'dict'>

# %%
print len(object_json["results"])
# Out:
# 10

# %%
print object_json[u"results"][0][u'content']
# Out:
# 26 Sep 2014 <b>...</b> “No soy un <b>corrupto</b>”, proclamó dramáticamente Jordi Pujol, 84 años, fundador
# del moderno nacionalismo catalán, y gobernante durante 23&nbsp;...

# %%
print object_json[u"results"][0][u"title"]
# Out:
# No soy un <b>corrupto</b>, se defendió Jordi Pujol ante el Parlamento catalán

# %%
print object_json[u"results"][0][u"clicktrackUrl"]
# Out:
# https://www.google.com/url?q=http://www.clarin.com/mundo/corrupto-defendio-Jordi-Pujol-Parlamento_0_1219678126.html&sa=U&ved=0CAUQFjAAOApqFQoTCPrwgfupyccCFVAQkgodAWUFSw&client=internal-uds-cse&usg=AFQjCNE11cE9m0kzg0VPeO3tmZox8C6BMw

# %%
page = response.text
soup = BeautifulSoup(page)

print soup
# Out:
# <html><body><p>// API callback
# ...

# %%
https://www.googleapis.com/customsearch/v1element?key=AIzaSyCVAXiUzRYsML1Pv6RwSG1gunmMikTzQqY&
    rsz=filtered_cse&num=10&hl=es&prettyPrint=false&source=gcsc&gss=.com&sig=56f70d816baa48bdfe9284ebc883ad41&
    start=10&cx=002843853682434280739:x9oyo5xw8ls&q=corrupcion&sort=&googlehost=www.google.com&
        callback=google.search.Search.apiary19326&nocache=1440530302936'

# %%
https://www.googleapis.com/customsearch/v1element?key=AIzaSyCVAXiUzRYsML1Pv6RwSG1gunmMikTzQqY&rsz=filtered_cse&num=10&hl=es&prettyPrint=false&source=gcsc&gss=.com&sig=56f70d816baa48bdfe9284ebc883ad41&start=20&cx=002843853682434280739:x9oyo5xw8ls&q=corrupcion&sort=&googlehost=www.google.com&callback=google.search.Search.apiary19326&nocache=1440530302936'

# %%
import time
import requests
import json
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from requests.exceptions import ConnectionError

import pymongo
from pymongo import MongoClient
client = MongoClient("52.25.140.201",27017)
db = client['ProjectCorruption']
print db
collection = db['Links_to_articles']
print collection

starting_point = 0

keyword = '"enriquecimiento%20ilícito"'

url_1 = 'https://www.googleapis.com/customsearch/v1element?key=AIzaSyCVAXiUzRYsML1Pv6RwSG1gunmMikTzQqY&rsz=filtered_cse&num=10&hl=es&prettyPrint=false&source=gcsc&gss=.com&sig=56f70d816baa48bdfe9284ebc883ad41&start=10&cx=002843853682434280739:x9oyo5xw8ls&q='
url_2 = '&sort=&googlehost=www.google.com&callback=google.search.Search.apiary7242&nocache=1440602392013'
url = url_1 + keyword + url_2

site_page = 1

response = requests.get(url)

while ((response.status_code == 200)):

    print "Page:",site_page
    print url
    
    page = response.text
    a = len(page)
    pos = page.index('{')
    object_json = json.loads(page[pos:a-2])
    
    for each in range(len(object_json["results"])):
        has = object_json[u"results"][each][u"clicktrackUrl"]
        if has != None:
            if 'http://www.clarin.com/' in has:
                article_link = has
                article_source = "Clarin"
                
                # Only adding the link if it is not existent currently
                exist = collection.find_one({"link": article_link})
                if exist == None:
                    article_object = {"link":article_link, "source":article_source}
                    article_id = collection.insert_one(article_object)
                    print 'Link added:',article_link
                else:
                    print 'Link passed:',article_link

    url_1 = 'https://www.googleapis.com/customsearch/v1element?key=AIzaSyCVAXiUzRYsML1Pv6RwSG1gunmMikTzQqY&rsz=filtered_cse&num=10&hl=es&prettyPrint=false&source=gcsc&gss=.com&sig=56f70d816baa48bdfe9284ebc883ad41&start='
    site_page = site_page + 1
    url_page = str(site_page*10)
    url_2 = '&cx=002843853682434280739:x9oyo5xw8ls&q='
    url_3 = '&sort=&googlehost=www.google.com&callback=google.search.Search.apiary7242&nocache=1440602392013'
    
    url = url_1+url_page+url_2+keyword+url_3
    
    resp_code = 1
    
    while True:
        try:
            response = requests.get(url)
        except ConnectionError:
            print "Oopss...we've been cut off... :( Let's take some time off :)"

        if response.status_code != 200:
            print "Sleeping..."
            time.sleep(12)
        else:
            break

print 'Grand Total added:',str(total_added)
# Out:
# Database(MongoClient('52.25.140.201', 27017), u'ProjectCorruption')
# Collection(Database(MongoClient('52.25.140.201', 27017), u'ProjectCorruption'), u'Links_to_articles')
# Page: 1
# https://www.googleapis.com/customsearch/v1element?key=AIzaSyCVAXiUzRYsML1Pv6RwSG1gunmMikTzQqY&rsz=filtered_cse&num=10&hl=es&prettyPrint=false&source=gcsc&gss=.com&sig=56f70d816baa48bdfe9284ebc883ad41&start=10&cx=002843853682434280739:x9oyo5xw8ls&q="enriquecimiento%20ilícito"&sort=&googlehost=www.google.com&callback=google.search.Search.apiary7242&nocache=1440602392013
# Link added: https://www.google.com/url?q=http://www.clarin.com/politica/imputo-segundo-Zannini-enriquecimiento-ilicito_0_1127287350.html&sa=U&ved=0CAUQFjAAOApqFQoTCLqCyuq_yccCFQt7kgod6VMB-w&client=internal-uds-cse&usg=AFQjCNHWnXkVTI1uLVP19l66ZrcJVOzARw
# ...
